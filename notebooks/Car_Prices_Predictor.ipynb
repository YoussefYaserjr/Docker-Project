# %%
import pandas as pd
import numpy as np
import re
import tensorflow as tf
import keras
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("D:\Car Prices Predictor\car.csv")
data.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_9400\915330941.py:1: SyntaxWarning: invalid escape sequence '\C'
#   data = pd.read_csv("D:\Car Prices Predictor\car.csv")
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#       Make             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# ...

# %%
x = set(data['Model'])

# %%
dict1 = {}
for i,n in enumerate(x):
    dict1[n] = i

# %%
data['car_model_classes'] = data['Model'].map(dict1)

# %%
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#       Make             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner Power Steering Remote Control  \
# 0                    Yes             Yes            Yes            Yes
# ...

# %%
x2 = set(data['Make'])
dict2 = {}
for n,i in enumerate(x2):
    dict2[i]=n
data['car_brand_classes'] = data['Make'].map(dict2)
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#       Make             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner Power Steering Remote Control  \
# 0                    Yes             Yes            Yes            Yes
# ...

# %%
x3 = set(data['Color'])
dict3 = {}
for n,i in enumerate(x3):
    dict3[i]=n
data['color_classes'] = data['Color'].map(dict3)
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#       Make             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner Power Steering Remote Control  \
# 0                    Yes             Yes            Yes            Yes
# ...

# %%
data = data.rename(columns={'Make':'Brand'})
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#      Brand             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner Power Steering Remote Control  \
# 0                    Yes             Yes            Yes            Yes
# ...

# %%
x4 = set(data['Automatic Transmission'])
dict4 = {'Yes':1,
          'No':0}
data['automatic_classes'] = data['Automatic Transmission'].map(dict4)
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#      Brand             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner Power Steering Remote Control  \
# 0                    Yes             Yes            Yes            Yes
# ...

# %%
x5 = set(data['Air Conditioner'])
dict5 = {'Yes':1,
          'No':0}
data['air_conditioner_classes'] = data['Air Conditioner'].map(dict5)
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#      Brand             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner Power Steering Remote Control  \
# 0                    Yes             Yes            Yes            Yes
# ...

# %%
x6 = set(data['Power Steering'])
dict6 = {'Yes':1,
          'No':0}
data['power_steering_classes'] = data['Power Steering'].map(dict6)
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#      Brand             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner Power Steering Remote Control  \
# 0                    Yes             Yes            Yes            Yes
# ...

# %%
x7 = set(data['Remote Control'])
dict7 = {'Yes':1,
          'No':0}
data['remote_control_classes'] = data['Remote Control'].map(dict7)
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#      Brand             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner Power Steering Remote Control  \
# 0                    Yes             Yes            Yes            Yes
# ...

# %%
def extract_year(y):
    match = re.search(r'\d{4}',y)
    if match : 
        return match.group()
    else :
        return 0

data['year'] = data['Name'].apply(extract_year)
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#      Brand             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner  ... Remote Control  \
# 0                    Yes             Yes  ...            Yes
# ...

# %%
def extract_miles(x):
    if isinstance(x,str):
        x = x.split()[0]
    return x
data['miles'] = data['Mileage'].apply(lambda x:extract_miles(x))
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#      Brand             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner  ...  \
# 0                    Yes             Yes  ...
# 1                    Yes             Yes  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33559 entries, 0 to 33558
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     33559 non-null  object
#  1   Price                    32625 non-null  object
#  2   Color                    33559 non-null  object
#  3   Mileage                  31440 non-null  object
#  4   Brand                    33559 non-null  object
#  5   Model                    33559 non-null  object
#  6   City                     33559 non-null  object
#  7   Date Displayed           33559 non-null  object
#  8   Automatic Transmission   33559 non-null  object
#  9   Air Conditioner          33559 non-null  object
#  10  Power Steering           33559 non-null  object
#  11  Remote Control           33559 non-null  object
#  12  Item URL                 33559 non-null  object
#  13  car_model_classes        33559 non-null  int64
# ...

# %%
set(data['year'])
# Out:
# {0,
#  '1007',
#  '1100',
#  '1200',
#  '1300',
#  '1500',
#  '1963',
#  '1970',
#  '1971',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2023',
#  '2024',
#  '2105',
#  '2106',
#  '2107',
#  '2110',
#  '2111',
#  '3008',
#  '5008'}

# %%
data['Year'] = data['year'].apply(lambda x :x if int(x)>=1963 and int(x)<=2025 else np.nan)
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 1            Chery Arrizo 5 2022            NaN     Bronze   86,000 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
#
#      Brand             Model                 City Date Displayed  \
# 0      Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 1    Chery          Arrizo 5            Nasr city     2024-02-16
# 2     Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3  Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4      BMW                X1                Cairo     2024-02-16
#
#   Automatic Transmission Air Conditioner  ... car_model_classes  \
# 0                    Yes             Yes  ...               186
# ...

# %%
set(data['Year'])
# Out:
# {'1963',
#  '1970',
#  '1971',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2023',
#  '2024',
#  nan}

# %%
data.isna().sum()
# Out:
# Name                          0
# Price                       934
# Color                         0
# Mileage                    2119
# Brand                         0
# Model                         0
# City                          0
# Date Displayed                0
# Automatic Transmission        0
# Air Conditioner               0
# Power Steering                0
# Remote Control                0
# Item URL                      0
# car_model_classes             0
# car_brand_classes             0
# color_classes                 0
# automatic_classes             0
# air_conditioner_classes       0
# power_steering_classes        0
# remote_control_classes        0
# year                          0
# miles                      2119
# Year                        295
# dtype: int64

# %%
data = data.dropna()

# %%
data.isna().sum()
# Out:
# Name                       0
# Price                      0
# Color                      0
# Mileage                    0
# Brand                      0
# Model                      0
# City                       0
# Date Displayed             0
# Automatic Transmission     0
# Air Conditioner            0
# Power Steering             0
# Remote Control             0
# Item URL                   0
# car_model_classes          0
# car_brand_classes          0
# color_classes              0
# automatic_classes          0
# air_conditioner_classes    0
# power_steering_classes     0
# remote_control_classes     0
# year                       0
# miles                      0
# Year                       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30835 entries, 0 to 33557
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     30835 non-null  object
#  1   Price                    30835 non-null  object
#  2   Color                    30835 non-null  object
#  3   Mileage                  30835 non-null  object
#  4   Brand                    30835 non-null  object
#  5   Model                    30835 non-null  object
#  6   City                     30835 non-null  object
#  7   Date Displayed           30835 non-null  object
#  8   Automatic Transmission   30835 non-null  object
#  9   Air Conditioner          30835 non-null  object
#  10  Power Steering           30835 non-null  object
#  11  Remote Control           30835 non-null  object
#  12  Item URL                 30835 non-null  object
#  13  car_model_classes        30835 non-null  int64
# ...

# %%
data['YEAR'] = data['Year'].apply(lambda x: int(x))
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30835 entries, 0 to 33557
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Name                     30835 non-null  object
#  1   Price                    30835 non-null  object
#  2   Color                    30835 non-null  object
#  3   Mileage                  30835 non-null  object
#  4   Brand                    30835 non-null  object
#  5   Model                    30835 non-null  object
#  6   City                     30835 non-null  object
#  7   Date Displayed           30835 non-null  object
#  8   Automatic Transmission   30835 non-null  object
#  9   Air Conditioner          30835 non-null  object
#  10  Power Steering           30835 non-null  object
#  11  Remote Control           30835 non-null  object
#  12  Item URL                 30835 non-null  object
#  13  car_model_classes        30835 non-null  int64
# ...

# %%
data.drop(['year','Year'],axis=1,inplace=True)
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
# 5           Chevrolet Optra 2021    700,000 EGP       Blue   75,000 Km
#
#        Brand             Model                 City Date Displayed  \
# 0        Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 2       Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3    Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4        BMW                X1                Cairo     2024-02-16
# 5  Chevrolet             Optra           Obour City     2024-02-16
#
#   Automatic Transmission Air Conditioner  ...  \
# 0                    Yes             Yes  ...
# ...

# %%
data = data.rename(columns={'YEAR':'year'})
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
# 5           Chevrolet Optra 2021    700,000 EGP       Blue   75,000 Km
#
#        Brand             Model                 City Date Displayed  \
# 0        Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 2       Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3    Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4        BMW                X1                Cairo     2024-02-16
# 5  Chevrolet             Optra           Obour City     2024-02-16
#
#   Automatic Transmission Air Conditioner  ...  \
# 0                    Yes             Yes  ...
# ...

# %%
data['Price'][0]
# Out:
# '2,800,000 EGP'

# %%
data['price'] = data['Price'].apply(lambda x: x.split()[0])
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
# 5           Chevrolet Optra 2021    700,000 EGP       Blue   75,000 Km
#
#        Brand             Model                 City Date Displayed  \
# 0        Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 2       Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3    Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4        BMW                X1                Cairo     2024-02-16
# 5  Chevrolet             Optra           Obour City     2024-02-16
#
#   Automatic Transmission Air Conditioner  ... car_model_classes  \
# 0                    Yes             Yes  ...               186
# ...

# %%
data['price11'] = data['price'].apply(lambda x: x.replace(',',''))
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
# 5           Chevrolet Optra 2021    700,000 EGP       Blue   75,000 Km
#
#        Brand             Model                 City Date Displayed  \
# 0        Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 2       Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3    Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4        BMW                X1                Cairo     2024-02-16
# 5  Chevrolet             Optra           Obour City     2024-02-16
#
#   Automatic Transmission Air Conditioner  ... car_brand_classes color_classes  \
# ...

# %%
data.drop(['price'],axis=1,inplace=True)

# %%
data = data.rename(columns={'price11':'price'})
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
# 5           Chevrolet Optra 2021    700,000 EGP       Blue   75,000 Km
#
#        Brand             Model                 City Date Displayed  \
# 0        Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 2       Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3    Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4        BMW                X1                Cairo     2024-02-16
# 5  Chevrolet             Optra           Obour City     2024-02-16
#
#   Automatic Transmission Air Conditioner  ... car_model_classes  \
# 0                    Yes             Yes  ...               186
# ...

# %%
data['miles11'] = data['miles'].apply(lambda x: x.replace(',',''))
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
# 5           Chevrolet Optra 2021    700,000 EGP       Blue   75,000 Km
#
#        Brand             Model                 City Date Displayed  \
# 0        Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 2       Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3    Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4        BMW                X1                Cairo     2024-02-16
# 5  Chevrolet             Optra           Obour City     2024-02-16
#
#   Automatic Transmission Air Conditioner  ... car_brand_classes color_classes  \
# ...

# %%
data.drop(['miles'],axis=1,inplace=True)
data = data.rename(columns={'miles11':'miles'})
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
# 5           Chevrolet Optra 2021    700,000 EGP       Blue   75,000 Km
#
#        Brand             Model                 City Date Displayed  \
# 0        Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 2       Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3    Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4        BMW                X1                Cairo     2024-02-16
# 5  Chevrolet             Optra           Obour City     2024-02-16
#
#   Automatic Transmission Air Conditioner  ... car_model_classes  \
# 0                    Yes             Yes  ...               186
# ...

# %%
list(set(data['Model']))
# Out:
# ['M70',
#  'A30 Shine',
#  'Lobo',
#  'A4',
#  'E 350',
#  'DS3',
#  '250',
#  'Cerato Koup',
#  'Corona',
#  'Pathfinder',
#  'Durango',
#  '3 Series',
#  'Toledo',
#  'Polo',
#  'X5 M',
#  'S2',
#  '7',
#  'S 320',
#  'Chery QQ',
#  'X3 Pro',
#  'C30',
#  'T-Roc',
#  'Kamiq',
#  'X3 M',
#  'ZS',
#  '605',
#  'DX3',
#  'Veryca',
#  'Taurus',
#  'Charmant',
#  '530',
#  'Jetta',
#  'Favorit',
#  'MZ 40',
#  'Accent HCI',
#  'X40',
#  'Golf 7',
#  '307',
#  'Eclipse',
#  'Grand i10',
#  'B 200',
#  'GLC 300',
#  'X25',
#  '1 Series',
#  'Eos',
#  '320',
#  'RX5 Plus',
#  'Soul',
#  'M11',
#  'Golf 2',
#  'C 300',
#  '545',
#  'Lancer Puma',
#  'E 220',
#  'C31',
#  'IX1',
#  'Attrage',
#  'Lancer Crystala',
#  'Mondeo',
#  'Jimny',
#  'Waja',
#  'Rodeo',
#  'Pajero',
#  'Aveo',
#  'Eado',
#  'A620',
#  'Clio',
#  'Velar',
#  'Regata',
#  'Emgrand 7',
#  'S60',
#  'Model X',
#  'S4',
#  'Altea',
#  'Territory',
#  'Tiggo 7 pro max',
#  'Haima 3',
#  'Cerato',
#  'GLC 200',
# ...

# %%
clear_data = data.drop(['Name','Price','Color','Mileage','Brand','Model','City','Date Displayed','Automatic Transmission','Air Conditioner','Power Steering','Remote Control'],axis=1)
clear_data.head()
# Out:
#                                             Item URL  car_model_classes  \
# 0  https://eg.hatla2ee.com/en/car/kia/sportage/62...                186
# 2   https://eg.hatla2ee.com/en/car/fiat/tipo/6286701                421
# 3  https://eg.hatla2ee.com/en/car/hyundai/Tucson-...                236
# 4      https://eg.hatla2ee.com/en/car/bmw/x1/6254123                274
# 5  https://eg.hatla2ee.com/en/car/chevrolet/optra...                809
#
#    car_brand_classes  color_classes  automatic_classes  \
# 0                  3              9                  1
# 2                 24              5                  1
# 3                 14             17                  1
# 4                 82             15                  1
# 5                 52              2                  1
#
#    air_conditioner_classes  power_steering_classes  remote_control_classes  \
# 0                        1                       1                       1
# ...

# %%
clear_data.drop(['Item URL'],axis=1,inplace=True)
clear_data.head()
# Out:
#    car_model_classes  car_brand_classes  color_classes  automatic_classes  \
# 0                186                  3              9                  1
# 2                421                 24              5                  1
# 3                236                 14             17                  1
# 4                274                 82             15                  1
# 5                809                 52              2                  1
#
#    air_conditioner_classes  power_steering_classes  remote_control_classes  \
# 0                        1                       1                       1
# 2                        1                       1                       1
# 3                        1                       1                       1
# 4                        1                       1                       1
# 5                        1                       1                       1
#
#    year    price   miles
# 0  2024  2800000     300
# ...

# %%
data.shape
# Out:
# (30835, 23)

# %%
data.head()
# Out:
#                             Name          Price      Color     Mileage  \
# 0              Kia Sportage 2024  2,800,000 EGP  Dark grey      300 Km
# 2                 Fiat Tipo 2021  1,200,000 EGP  Petroleum  131,000 Km
# 3  Hyundai Tucson Turbo GDI 2021  2,050,000 EGP      Black  125,000 Km
# 4                    BMW X1 2018  2,050,000 EGP       Gray   84,000 Km
# 5           Chevrolet Optra 2021    700,000 EGP       Blue   75,000 Km
#
#        Brand             Model                 City Date Displayed  \
# 0        Kia          Sportage  Tagamo3 - New Cairo     2024-02-16
# 2       Fiat              Tipo       Kafr el-Dawwar     2024-02-16
# 3    Hyundai  Tucson Turbo GDI            Nasr city     2024-02-16
# 4        BMW                X1                Cairo     2024-02-16
# 5  Chevrolet             Optra           Obour City     2024-02-16
#
#   Automatic Transmission Air Conditioner  ... car_model_classes  \
# 0                    Yes             Yes  ...               186
# ...

# %%
v = 0
for n,i in enumerate(data['Model']):
    if i == "Sportage":
        v = n

# %%
data['power_steering_classes'][v]
# Out:
# 1

# %%
clear_data.corr()
# Out:
#                          car_model_classes  car_brand_classes  color_classes  \
# car_model_classes                 1.000000          -0.044818      -0.023732
# car_brand_classes                -0.044818           1.000000       0.051270
# color_classes                    -0.023732           0.051270       1.000000
# automatic_classes                -0.074468           0.054930       0.041292
# air_conditioner_classes           0.035288          -0.029886       0.056631
# power_steering_classes            0.015235          -0.056475       0.020705
# remote_control_classes            0.033774          -0.061807      -0.014678
# year                              0.089537          -0.016200      -0.024120
# price                            -0.182555          -0.039905       0.040216
# miles                             0.039398          -0.036949       0.036356
#
#                          automatic_classes  air_conditioner_classes  \
# ...

# %%
clear_data = clear_data.rename(columns={'New_Price':'price'})
clear_data.head()
# Out:
#    car_model_classes  car_brand_classes  color_classes  automatic_classes  \
# 0                186                  3              9                  1
# 2                421                 24              5                  1
# 3                236                 14             17                  1
# 4                274                 82             15                  1
# 5                809                 52              2                  1
#
#    air_conditioner_classes  power_steering_classes  remote_control_classes  \
# 0                        1                       1                       1
# 2                        1                       1                       1
# 3                        1                       1                       1
# 4                        1                       1                       1
# 5                        1                       1                       1
#
#    year   miles    price
# 0  2024     300  2800000
# ...

# %%
clear_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30835 entries, 0 to 33557
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   car_model_classes        30835 non-null  int64
#  1   car_brand_classes        30835 non-null  int64
#  2   color_classes            30835 non-null  int64
#  3   automatic_classes        30835 non-null  int64
#  4   air_conditioner_classes  30835 non-null  int64
#  5   power_steering_classes   30835 non-null  int64
#  6   remote_control_classes   30835 non-null  int64
#  7   year                     30835 non-null  int64
#  8   miles                    30835 non-null  object
#  9   price                    30835 non-null  int64
# dtypes: int64(9), object(1)
# memory usage: 3.6+ MB

# %%
clear_data['Miles'] = clear_data['miles'].apply(lambda x: int(x))
clear_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30835 entries, 0 to 33557
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   car_model_classes        30835 non-null  int64
#  1   car_brand_classes        30835 non-null  int64
#  2   color_classes            30835 non-null  int64
#  3   automatic_classes        30835 non-null  int64
#  4   air_conditioner_classes  30835 non-null  int64
#  5   power_steering_classes   30835 non-null  int64
#  6   remote_control_classes   30835 non-null  int64
#  7   year                     30835 non-null  int64
#  8   miles                    30835 non-null  object
#  9   price                    30835 non-null  int64
#  10  Miles                    30835 non-null  int64
# dtypes: int64(10), object(1)
# memory usage: 3.8+ MB

# %%
clear_data.drop(['miles'],axis=1,inplace=True)
clear_data = clear_data.rename(columns={'Miles':'miles'})

# %%
X = clear_data.drop(['price'],axis=1)
y = clear_data['price']

# %%
from sklearn.feature_selection import SelectKBest, chi2
def feature_selection_by_num(X,y,num):
    selected_features = SelectKBest(score_func = chi2, k = num)
    X_selected = selected_features.fit_transform(X,y)
    selected = pd.DataFrame(X_selected, columns = [i for i,j in zip (X.columns, selected_features.get_support()) if j])
    selected['Output'] = y
    return selected
new2 = feature_selection_by_num(X,y,9)
new2
# Out:
#        car_model_classes  car_brand_classes  color_classes  automatic_classes  \
# 0                    186                  3              9                  1
# 1                    421                 24              5                  1
# 2                    236                 14             17                  1
# 3                    274                 82             15                  1
# 4                    809                 52              2                  1
# ...                  ...                ...            ...                ...
# 30830                258                  3             15                  1
# 30831                702                  6             17                  0
# 30832                518                 99              6                  1
# 30833                562                 58             17                  1
# 30834                620                 14              6                  0
#
# ...

# %%
clear_data['price'].max()
# Out:
# 16250000

# %%
clear_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30835 entries, 0 to 33557
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   car_model_classes        30835 non-null  int64
#  1   car_brand_classes        30835 non-null  int64
#  2   color_classes            30835 non-null  int64
#  3   automatic_classes        30835 non-null  int64
#  4   air_conditioner_classes  30835 non-null  int64
#  5   power_steering_classes   30835 non-null  int64
#  6   remote_control_classes   30835 non-null  int64
#  7   year                     30835 non-null  int64
#  8   price                    30835 non-null  int64
#  9   miles                    30835 non-null  int64
# dtypes: int64(10)
# memory usage: 3.6 MB

# %%
clear_data['New_Price'] = clear_data['price'].apply(lambda x: int(x))
clear_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30835 entries, 0 to 33557
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   car_model_classes        30835 non-null  int64
#  1   car_brand_classes        30835 non-null  int64
#  2   color_classes            30835 non-null  int64
#  3   automatic_classes        30835 non-null  int64
#  4   air_conditioner_classes  30835 non-null  int64
#  5   power_steering_classes   30835 non-null  int64
#  6   remote_control_classes   30835 non-null  int64
#  7   year                     30835 non-null  int64
#  8   price                    30835 non-null  object
#  9   miles                    30835 non-null  object
#  10  New_Price                30835 non-null  int64
# dtypes: int64(9), object(2)
# memory usage: 3.8+ MB

# %%
clear_data.drop(['price'],axis=1,inplace=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=44, shuffle = True)

# %%
y_train[:20]
# Out:
# 30157    1000000
# 4873     2850000
# 12921     485000
# 22889     300000
# 13108     345000
# 7134      320000
# 30370     475000
# 2419     1000030
# 1769     1150000
# 18092     400000
# 30054    2200000
# 21270    1950000
# 20625      58000
# 8628      370000
# 8160      850000
# 2550      470000
# 30667     285000
# 25809     300000
# 25248     700000
# 16620     750000
# Name: price, dtype: int64

# %%
Model = keras.models.Sequential([
    keras.layers.Dense(8, activation = 'sigmoid'),
    keras.layers.Dense(128, activation = 'sigmoid'),
    keras.layers.Dense(64, activation = 'sigmoid'),
    keras.layers.Dense(16, activation = 'sigmoid'),
    keras.layers.Dense(1, activation = 'relu')
    ])

# %%
Model.compile(optimizer='adam', loss = 'mse', metrics = ['mse'])

history = Model.fit(X_train, y_train,
                    validation_data = (X_test, y_test),
                     epochs = 100,
                     batch_size = 1000,
                     verbose = 1,
                     callbacks = [tf.keras.callbacks.EarlyStopping(patience = 10,
                                                                   monitor='val_loss',
                                                                   restore_best_weights = True)]
                    )
# Out:
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2028767281152.0000 - mse: 2028767281152.0000 - val_loss: 2097098522624.0000 - val_mse: 2097098522624.0000
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2019806281728.0000 - mse: 2019806281728.0000 - val_loss: 2097098522624.0000 - val_mse: 2097098522624.0000
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1995377606656.0000 - mse: 1995377606656.0000 - val_loss: 2097098522624.0000 - val_mse: 2097098522624.0000
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1922649423872.0000 - mse: 1922649423872.0000 - val_loss: 2097098522624.0000 - val_mse: 2097098522624.0000
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1991605485568.0000 - mse: 1991605485568.0000 - val_loss: 2097098522624.0000 - val_mse: 2097098522624.0000
# Epoch 6/100
# ...

# %%
RandomForestRegressorModel = RandomForestRegressor(n_estimators=1500,max_depth=10, random_state=44)
RandomForestRegressorModel.fit(X_train, y_train)

y_pred = RandomForestRegressorModel.predict(X_test)

RandomForestRegressorModel.fit(X_train, y_train)
print(f'Train Score is : {RandomForestRegressorModel.score(X_train, y_train)}')
print(f'Test Score is : {RandomForestRegressorModel.score(X_test, y_test)}')
# Out:
# Train Score is : 0.9025434906003159
# Test Score is : 0.8092046288593133

# %%
MSE = mean_squared_error(y_pred, y_test, multioutput = 'uniform_average')
MSE
# Out:
# 223993242343.52966

# %%
import pickle
with open("car_prices.pk1", "wb") as f:
    pickle.dump(Model,f)

# %%
clear_data.head()
# Out:
#    car_model_classes  car_brand_classes  color_classes  automatic_classes  \
# 0                186                  3              9                  1
# 2                421                 24              5                  1
# 3                236                 14             17                  1
# 4                274                 82             15                  1
# 5                809                 52              2                  1
#
#    air_conditioner_classes  power_steering_classes  remote_control_classes  \
# 0                        1                       1                       1
# 2                        1                       1                       1
# 3                        1                       1                       1
# 4                        1                       1                       1
# 5                        1                       1                       1
#
#    year    price   miles
# 0  2024  2800000     300
# ...
